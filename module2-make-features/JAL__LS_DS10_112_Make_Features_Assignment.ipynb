# %% [markdown]
# <a href="https://colab.research.google.com/github/ThisIsJorgeLima/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module2-make-features/JAL__LS_DS10_112_Make_Features_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
##### Begin Working Here #####

# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2019-10-30 00:33:35--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip.1’
#
# LoanStats_2018Q4.cs     [                <=> ]  21.62M   306KB/s    in 73s
#
# 2019-10-30 00:34:49 (303 KB/s) - ‘LoanStats_2018Q4.csv.zip.1’ saved [22667400]

# %%
# !unzip LoanStats_2018Q4.csv.zip
# Out:
# Archive:  LoanStats_2018Q4.csv.zip
# replace LoanStats_2018Q4.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('LoanStats_2018Q4.csv', header=1, skipfooter=2)
print(df.shape)

df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
# (128412, 144)
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      20000        20000          20000.0   36 months
# 1 NaN        NaN      25000        25000          25000.0   60 months
# 2 NaN        NaN      26500        26500          26500.0   60 months
# 3 NaN        NaN      10400        10400          10400.0   36 months
# 4 NaN        NaN      35000        35000          35000.0   60 months
#
#   int_rate  installment grade sub_grade                         emp_title  \
# 0   14.47%       688.13     C        C2                        bus driver
# 1   16.14%       609.82     C        C4                Production Manager
# ...

# %%
# !tail LoanStats_2018Q4.csv
# Out:
# "","","5600","5600","5600"," 36 months"," 13.56%","190.21","C","C1","","n/a","RENT","15600","Not Verified","Oct-2018","Current","n","","","credit_card","Credit card refinancing","836xx","ID","15.31","0","Aug-2012","0","","97","9","1","5996","34.5%","11","w","4122.15","4122.15","2081.76","2081.76","1477.85","603.91","0.0","0.0","0.0","Sep-2019","190.21","Oct-2019","Sep-2019","0","","1","Individual","","","","0","0","5996","0","0","0","1","20","0","","0","2","3017","35","17400","1","0","0","3","750","4689","45.5","0","0","20","73","13","13","0","13","","20","","0","3","5","4","4","1","9","10","5","9","0","0","0","0","100","25","1","0","17400","5996","8600","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# ...

# %%
df.dtypes
# Out:
# id                                            float64
# member_id                                     float64
# loan_amnt                                       int64
# funded_amnt                                     int64
# funded_amnt_inv                               float64
# term                                           object
# int_rate                                       object
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# ...

# %%
df.isnull().sum().sort_values()
# Out:
# inq_fi                                             0
# delinq_amnt                                        0
# chargeoff_within_12_mths                           0
# acc_open_past_24mths                               0
# inq_last_12m                                       0
# total_cu_tl                                        0
# total_rev_hi_lim                                   0
# max_bal_bc                                         0
# open_rv_24m                                        0
# open_rv_12m                                        0
# total_bal_il                                       0
# open_il_24m                                        0
# hardship_flag                                      0
# open_act_il                                        0
# open_acc_6m                                        0
# tot_cur_bal                                        0
# tot_coll_amt                                       0
# acc_now_delinq                                     0
# ...

# %%
df1 = df.drop(['url','member_id','desc','id'],axis=1)

# %%
df1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      20000        20000          20000.0   36 months   14.47%       688.13
# 1      25000        25000          25000.0   60 months   16.14%       609.82
# 2      26500        26500          26500.0   60 months   11.31%       580.28
# 3      10400        10400          10400.0   36 months   12.98%       350.32
# 4      35000        35000          35000.0   60 months   12.98%       796.00
#
#   grade sub_grade                         emp_title emp_length home_ownership  \
# 0     C        C2                        bus driver    4 years            OWN
# 1     C        C4                Production Manager    5 years       MORTGAGE
# 2     B        B3               Compliance Director  10+ years       MORTGAGE
# 3     B        B5        Program Support Assistant   10+ years       MORTGAGE
# 4     B        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
# ...

# %%
df['term'][:10]
# Out:
# 0     36 months
# 1     60 months
# 2     60 months
# 3     36 months
# 4     60 months
# 5     36 months
# 6     36 months
# 7     60 months
# 8     36 months
# 9     60 months
# Name: term, dtype: object

# %%
# These next steps I'll be defining the function to remove 'months'
df['term'][:10].iloc[0]
# Out:
# ' 36 months'

# %%
term = ' 36 months'

# %%
# removing whitespace by using .strip()
term.strip('months')
# Out:
# ' 36 '

# %%
type(term.strip().strip('months'))
# Out:
# str

# %%
def str_months_to_int(term_str_to_int):
  return int(term_str_to_int.strip().strip('months').strip())

# %%
#Function is being applied to the term column
df['term'].apply(str_months_to_int)
# Out:
# 0         36
# 1         60
# 2         60
# 3         36
# 4         60
#           ..
# 128407    36
# 128408    36
# 128409    36
# 128410    36
# 128411    36
# Name: term, Length: 128412, dtype: int64

# %%
# Now after applying we can see that under the term column.
# We no longer have months.
df1['term'] = df['term'].apply(str_months_to_int)
df1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term int_rate  installment grade  \
# 0      20000        20000          20000.0    36   14.47%       688.13     C
# 1      25000        25000          25000.0    60   16.14%       609.82     C
# 2      26500        26500          26500.0    60   11.31%       580.28     B
# 3      10400        10400          10400.0    36   12.98%       350.32     B
# 4      35000        35000          35000.0    60   12.98%       796.00     B
#
#   sub_grade                         emp_title emp_length home_ownership  \
# 0        C2                        bus driver    4 years            OWN
# 1        C4                Production Manager    5 years       MORTGAGE
# 2        B3               Compliance Director  10+ years       MORTGAGE
# 3        B5        Program Support Assistant   10+ years       MORTGAGE
# 4        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
#    annual_inc verification_status   issue_d loan_status pymnt_plan  \
# ...

# %%
df1['loan_status_is_great'] = df1['loan_status'].str.contains('Current','Fully Paid')

df1.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term int_rate  installment grade  \
# 0      20000        20000          20000.0     1   14.47%       688.13     C
# 1      25000        25000          25000.0     1   16.14%       609.82     C
# 2      26500        26500          26500.0     1   11.31%       580.28     B
# 3      10400        10400          10400.0     1   12.98%       350.32     B
# 4      35000        35000          35000.0     1   12.98%       796.00     B
#
#   sub_grade                         emp_title emp_length home_ownership  \
# 0        C2                        bus driver    4 years            OWN
# 1        C4                Production Manager    5 years       MORTGAGE
# 2        B3               Compliance Director  10+ years       MORTGAGE
# 3        B5        Program Support Assistant   10+ years       MORTGAGE
# 4        B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
#
#    annual_inc verification_status   issue_d loan_status pymnt_plan  \
# ...

# %% [markdown]
# # **Part ii**
#
#
# Make a column named loan_status_is_great. It should contain the integer 1 if loan_status is "Current" or "Fully Paid." Else it should contain the integer 0.

# %%
condition = (df1['loan_status_is_great']==True)
condition
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4          True
#           ...
# 128407    False
# 128408    False
# 128409    False
# 128410    False
# 128411     True
# Name: loan_status_is_great, Length: 128412, dtype: bool

# %%
loan_status_is_great = df1 [condition]
loan_status_is_great.head()
# Out:
#     loan_amnt  funded_amnt  funded_amnt_inv  term int_rate  installment grade  \
# 1       25000        25000          25000.0     1   16.14%       609.82     C
# 4       35000        35000          35000.0     1   12.98%       796.00     B
# 8       12000        12000          12000.0     1   11.80%       397.43     B
# 16      12000        12000          12000.0     1   16.14%       422.72     C
# 18      20400        20400          20400.0     1   10.33%       436.76     B
#
#    sub_grade                         emp_title emp_length home_ownership  \
# 1         C4                Production Manager    5 years       MORTGAGE
# 4         B5  Sr. Vice President -Risk Manager    7 years       MORTGAGE
# 8         B4            Transportation Manager  10+ years           RENT
# 16        C4             Sales Account Manager    4 years           RENT
# 18        B1                    Bakery Manager  10+ years       MORTGAGE
#
# ...

# %%
loan_status_is_great.describe()
# Out:
#           loan_amnt   funded_amnt  funded_amnt_inv     term   installment  \
# count  14072.000000  14072.000000     14072.000000  14072.0  14072.000000
# mean   17692.310972  17692.310972     17689.571489      1.0    505.131804
# std    10414.218294  10414.218294     10416.008955      0.0    290.189897
# min     1000.000000   1000.000000       750.000000      1.0     30.640000
# 25%    10000.000000  10000.000000     10000.000000      1.0    287.865000
# 50%    15000.000000  15000.000000     15000.000000      1.0    451.450000
# 75%    25000.000000  25000.000000     25000.000000      1.0    679.290000
# max    40000.000000  40000.000000     40000.000000      1.0   1498.300000
#
#          annual_inc           dti   delinq_2yrs  inq_last_6mths  \
# count  1.407200e+04  14071.000000  14072.000000    14072.000000
# mean   9.516966e+04     19.095499      0.233940        0.445210
# std    1.016816e+05     11.260063      0.761143        0.733173
# ...

# %%
#if loan_status is "Current" or "Fully Paid." 
# Else it should contain the integer 0.

def loan_cleaning(loan):
  if loan in ['Current','Fully Paid']:
    return '1'
  else:
    return '0'

# %%
df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term int_rate  \
# 0 NaN        NaN      20000        20000          20000.0     1   14.47%
# 1 NaN        NaN      25000        25000          25000.0     1   16.14%
# 2 NaN        NaN      26500        26500          26500.0     1   11.31%
# 3 NaN        NaN      10400        10400          10400.0     1   12.98%
# 4 NaN        NaN      35000        35000          35000.0     1   12.98%
#
#    installment grade sub_grade                         emp_title emp_length  \
# 0       688.13     C        C2                        bus driver    4 years
# 1       609.82     C        C4                Production Manager    5 years
# 2       580.28     B        B3               Compliance Director  10+ years
# 3       350.32     B        B5        Program Support Assistant   10+ years
# 4       796.00     B        B5  Sr. Vice President -Risk Manager    7 years
#
# ...

# %%
df ['loan_status_is_great'] = df['loan_status'].apply(loan_cleaning)
df['loan_status_is_great'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: loan_status_is_great, dtype: object

# %% [markdown]
# # **Part iii**
#
#
# Make
# last_pymnt_d_month and last_pymnt_d_year columns:

# %%
import pandas as pd
pd.options.display.max_rows = 999
pd.options.display.max_columns = 100

print(df.shape)
df.head()
# Out:
# (128412, 147)
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      20000        20000          20000.0   36 months
# 1 NaN        NaN      25000        25000          25000.0   60 months
# 2 NaN        NaN      26500        26500          26500.0   60 months
# 3 NaN        NaN      10400        10400          10400.0   36 months
# 4 NaN        NaN      35000        35000          35000.0   60 months
#
#   int_rate  installment grade sub_grade                         emp_title  \
# 0   14.47%       688.13     C        C2                        bus driver
# 1   16.14%       609.82     C        C4                Production Manager
# 2   11.31%       580.28     B        B3               Compliance Director
# 3   12.98%       350.32     B        B5        Program Support Assistant
# 4   12.98%       796.00     B        B5  Sr. Vice President -Risk Manager
#
#   emp_length home_ownership  annual_inc verification_status   issue_d  \
# ...

# %%
df.tail(5)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 128407 NaN        NaN      23000        23000          23000.0   36 months
# 128408 NaN        NaN      10000        10000          10000.0   36 months
# 128409 NaN        NaN       5000         5000           5000.0   36 months
# 128410 NaN        NaN      10000        10000           9750.0   36 months
# 128411 NaN        NaN      10000        10000          10000.0   36 months
#
#        int_rate  installment grade sub_grade             emp_title emp_length  \
# 128407   15.02%       797.53     C        C3        Tax Consultant  10+ years
# 128408   15.02%       346.76     C        C3        security guard    5 years
# 128409   13.56%       169.83     C        C1          Payoff Clerk  10+ years
# 128410   11.06%       327.68     B        B3                   NaN        NaN
# 128411   16.91%       356.08     C        C5  Key Accounts Manager    2 years
#
# ...

# %%
df['last_pymnt_d'] = pd.to_datetime(df['last_pymnt_d'], infer_datetime_format= True)

# %%
df['last_pymnt_d'].head()
# Out:
# 0   2019-09-01
# 1   2019-04-01
# 2   2019-09-01
# 3   2019-09-01
# 4   2019-04-01
# Name: last_pymnt_d, dtype: datetime64[ns]

# %%
df.head(1)
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      20000        20000          20000.0   36 months
#
#   int_rate  installment grade sub_grade   emp_title emp_length home_ownership  \
# 0   14.47%       688.13     C        C2  bus driver    4 years            OWN
#
#    annual_inc verification_status   issue_d loan_status pymnt_plan  url  desc  \
# 0     52000.0     Source Verified  Dec-2018     Current          n  NaN   NaN
#
#               purpose               title zip_code addr_state    dti  \
# 0  debt_consolidation  Debt consolidation    681xx         NE  30.65
#
#    delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0            1         Jun-1979               2                    15.0
#
#    mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 0                     NaN         6        0      15048        73%         22
#
# ...

# %%
df['last_pymnt_d_month']= df['last_pymnt'].dt.month

# %%
df['last_pymnt_d_month'][:5]
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: last_pymnt_d_month, dtype: float64

# %%
df['last_pymnt_d_year']= df['last_pymnt'].dt.year

# %%
df['last_pymnt_d_year'][:5]
# Out:
# 0    1970.0
# 1    1970.0
# 2    1970.0
# 3    1970.0
# 4    1970.0
# Name: last_pymnt_d_year, dtype: float64

# %%
df.dtypes
# Out:
# id                                                   float64
# member_id                                            float64
# loan_amnt                                              int64
# funded_amnt                                            int64
# funded_amnt_inv                                      float64
# term                                                  object
# int_rate                                              object
# installment                                          float64
# grade                                                 object
# sub_grade                                             object
# emp_title                                             object
# emp_length                                            object
# home_ownership                                        object
# annual_inc                                           float64
# verification_status                                   object
# ...

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
